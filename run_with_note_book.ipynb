# %%
# !git clone https://github.com/drhspeco/diffit-lora.git
# Out:
# Cloning into 'diffit-lora'...
# remote: Enumerating objects: 69, done.
# remote: Counting objects: 100% (69/69), done.
# remote: Compressing objects: 100% (61/61), done.
# remote: Total 69 (delta 9), reused 66 (delta 6), pack-reused 0 (from 0)
# Receiving objects: 100% (69/69), 72.71 KiB | 12.12 MiB/s, done.
# Resolving deltas: 100% (9/9), done.

# %%
# %cd diffit-lora
# Out:
# /content/diffit-lora

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 5.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.5/83.5 kB 9.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 5.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 832.4/832.4 kB 23.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.2/983.2 kB 68.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 19.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.8/53.8 kB 6.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 79.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.2/94.2 kB 11.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.9/57.9 kB 7.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.6/63.6 kB 8.0 MB/s eta 0:00:00
# ...

# %%
# Out:
# /content/diffit-lora

# %%
# !git pull
# !pip install -e .

# %%
# !diffit-generate --checkpoint /content/best_model.ckpt --num-samples 16 --output /content/samples/
# Out:
# 🚀 Using device: cuda
# 📥 Loading model from /content/best_model.ckpt
# ✅ Model loaded successfully
# 🎨 Generating 16 samples...
# 📊 Generating batch 1/1 (16 samples)
# sampling loop time step: 100% 500/500 [00:42<00:00, 11.79it/s]
# ✅ Generated 16 samples
# 💾 Saved 16 images to /content/samples/
# 🎉 Generation completed successfully!

# %%
# !python scripts/finetune_with_lora.py --base-checkpoint /content/best_model.ckpt --config configs/training/lora_finetuning.yaml
# Out:
# 🚀 Starting DiffiT LoRA Fine-tuning
# ...
# Training config: configs/training/lora_finetuning.yaml
# Base checkpoint: /content/best_model.ckpt
# LoRA config: configs/lora/blockwise_config.yaml
# Output directory: ./weights/lora_finetuned/
# ...
# ✅ Created image-space DiffiT model
# ✅ Data module configured
# ✅ PyTorch Lightning trainer configured
# ⚠️ Could not load pretrained weights: [Errno 2] No such file or directory: './weights/ImageSpaceWeights/best_model.ckpt'
# Continuing with randomly initialized weights
# 📊 Before LoRA: 4,636,609 parameters
# ✅ Block-wise LoRA injection complete!
# 📊 Successfully replaced 30 linear layers:
#    • diffit_res_block_group_1.diffit_res_block.diffit_block.tmsa.Wqs -> rank 12
#    • diffit_res_block_group_1.diffit_res_block.diffit_block.tmsa.Wks -> rank 12
#    • diffit_res_block_group_1.diffit_res_block.diffit_block.tmsa.Wvs -> rank 12
#    • diffit_res_block_group_1.diffit_res_block.diffit_block.tmsa.Wqt -> rank 12
# ...
